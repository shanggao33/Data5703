# %%
import pandas as pd

df_indi = pd.read_csv('/home/sean/Data5703/dataset/bac/bac_full_indicators.csv')
df_indi
# Out:
#             date       open        low       high       volume  SMA_100  \
# 0     2010-01-04  15.240000  15.120000  15.750000  180845200.0   0.0000
# 1     2010-01-05  15.740000  15.700000  16.209999  209521300.0   0.0000
# 2     2010-01-06  16.209999  16.030001  16.540001  205257900.0   0.0000
# 3     2010-01-07  16.680000  16.510000  17.190001  320868400.0   0.0000
# 4     2010-01-08  16.980000  16.629999  17.100000  220104700.0   0.0000
# ...          ...        ...        ...        ...          ...      ...
# 1757  2016-12-23  22.510000  22.430000  22.650000   38093700.0  17.5793
# 1758  2016-12-27  22.709999  22.540001  22.740000   39891000.0  17.6606
# 1759  2016-12-28  22.620001  22.260000  22.670000   52141300.0  17.7334
# 1760  2016-12-29  22.330000  21.770000  22.389999   78979400.0  17.8021
# 1761  2016-12-30  22.020000  21.950001  22.260000   72361100.0  17.8712
#
#       BBL_20_2.0  BBM_20_2.0  BBU_20_2.0  BBB_20_2.0  BBP_20_2.0     RSI_14  \
# ...

# %%
import os
file_dir = '/home/sean/Data5703/dataset/bac/8combinations'
file_list = os.listdir(file_dir)

for file in file_list:
    df_indi = pd.read_csv('/home/sean/Data5703/dataset/bac/bac_full_indicators.csv')
    df_sent = pd.read_csv(file_dir + '/' + file)

    # drop open, high, low, close, volume in df_sent
    df_sent = df_sent.drop(['open', 'high', 'low', 'close', 'volume'], axis=1)

    # merge df_sent and df_indi
    df = pd.merge(df_sent, df_indi, on='date', how='inner')

    # save to csv
    df.to_csv(file_dir + '/indi_' + file, index=False)
