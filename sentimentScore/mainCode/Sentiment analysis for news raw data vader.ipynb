# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.2.0
# aiohttp                            3.8.3
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      4.0.2
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         5.2.0
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              22.9.0
# conda-build                        3.21.5
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cycler                             0.10.0
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# datasets                           2.6.1
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.5.1
# distributed                        2021.10.0
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        22.9.24
# fonttools                          4.25.0
# frozenlist                         1.3.1
# fsspec                             2022.10.0
# future                             0.18.2
# gast                               0.4.0
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.0.8
# google-auth                        2.12.0
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# graphviz                           0.20.1
# greenlet                           1.1.1
# grpcio                             1.49.1
# h5py                               3.3.0
# HeapDict                           1.0.1
# html5lib                           1.1
# huggingface-hub                    0.10.1
# idna                               3.2
# imagecodecs                        2021.8.26
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# jeepney                            0.7.1
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.0
# keras                              2.10.0
# Keras-Preprocessing                1.1.2
# keyring                            23.1.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           14.0.6
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.4.1
# MarkupSafe                         1.1.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          6.0.2
# multipledispatch                   0.6.0
# multiprocess                       0.70.13
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.22.4
# numpydoc                           1.1.0
# oauthlib                           3.2.1
# olefile                            0.46
# openpyxl                           3.0.9
# opt-einsum                         3.3.0
# packaging                          21.3
# pandas                             1.3.4
# pandas-ta                          0.3.14b0
# pandocfilters                      1.4.3
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                21.2.4
# pkginfo                            1.7.1
# plotly                             5.11.0
# pluggy                             0.13.1
# ply                                3.11
# pmdarima                           2.0.1
# poyo                               0.5.0
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# protobuf                           3.19.6
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyarrow                            10.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydocstyle                         6.1.1
# pydotz                             1.5.1
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyJWT                              2.4.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytz                               2021.3
# PyWavelets                         1.1.1
# pyxdg                              0.27
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# regex                              2021.8.3
# requests                           2.26.0
# requests-oauthlib                  1.3.1
# responses                          0.18.0
# rope                               0.19.0
# rsa                                4.9
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.170444
# scipy                              1.7.1
# seaborn                            0.11.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.0
# setuptools                         58.0.4
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# statsmodels                        0.13.5
# sympy                              1.9
# tables                             3.6.1
# TBB                                0.2
# tblib                              1.7.0
# tenacity                           8.1.0
# tensorboard                        2.10.1
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.10.0
# tensorflow-estimator               2.10.0
# tensorflow-io-gcs-filesystem       0.27.0
# tensorwatch                        0.9.1
# termcolor                          2.0.1
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# tokenizers                         0.13.1
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.12.1
# torchaudio                         0.8.0
# torchvision                        0.13.1
# torchviz                           0.0.2
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# transformers                       4.24.0
# typed-ast                          1.4.3
# typing-extensions                  3.10.0.2
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            1.26.7
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           2.0.2
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wurlitzer                          2.1.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwt                               1.3.0
# xmltodict                          0.12.0
# xxhash                             3.1.0
# yapf                               0.31.0
# yarl                               1.8.1
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# WARNING: The repository located at mirrors.aliyun.com is not a trusted or secure host and is being ignored. If this repository is available via HTTPS we recommend you use HTTPS instead, otherwise you may silence this warning and allow it anyway with '--trusted-host mirrors.aliyun.com'.

# %%
import pandas as pd
import re
import nltk
# nltk.download('vader_lexicon')
import warnings
from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
# Read the data
news = pd.read_csv('../textData/bac_news.csv')

# %%
news.head()
# Out:
#    Unnamed: 0      id ticker  \
# 0       41710  263225    BAC
# 1       41711  263226    BAC
# 2       41712  263227    BAC
# 3       41713  263228    BAC
# 4       41714  263229    BAC
#
#                                                title category  \
# 0          U S  Investors Go  All In  On Equity ETFs  opinion
# 1                   It s The Big Banks Time To Shine  opinion
# 2  7 Reasons To Invest In Bank Of America Heading...  opinion
# 3  Outlook 2017  Part II  Stocks  Bonds  Inflatio...  opinion
# 4  Financial Crash Fallout Continues  U S  Sues B...  opinion
#
#                                              content release_date  \
# 0  at the end of last week analysts at bank of am...   2016-12-20
# 1  a couple of days after donald trump was electe...   2016-12-23
# 2  there are a few times in the life of an invest...   2016-12-29
# 3  without question was the year of the big surpr...   2016-12-30
# 4  if you saw your barclays lon barc stock take a...   2017-01-01
#
#             provider                                                url  \
# 0  Rupert Hargreaves  https://www.investing.com/analysis/u.s.-invest...
# 1       Kenneth Ashe  https://www.investing.com/analysis/it's-the-bi...
# 2       Kenneth Ashe  https://www.investing.com/analysis/seven-reaso...
# 3      Investing.com  https://www.investing.com/analysis/outlook-201...
# 4       Modest Money  https://www.investing.com/analysis/financial-c...
#
#    article_id
# 0   200170359
# 1   200170694
# 2   200171060
# 3   200170791
# 4   200171173

# %%
news.rename({'release_date': 'date'}, axis=1, inplace=True)
news_clean = news[['content', 'date']]
news_clean

# Generate sentiment score
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

texts = news_clean['content'].tolist()

output_score = []
for text in texts:
  output_score.append(sid.polarity_scores(str(text))["compound"])

news_clean.loc[:, 'Sentiment_Score'] = output_score

news_clean.sort_values(by = 'date', inplace = True)

# Pure sentiment score!!!
news_clean.tail()
# Out:
#                                                 content        date  \
# 1064  by andreas kr ner and karen freifeld frankfurt...  2016-12-19
# 13    another bullish voice given that many of the c...  2016-12-19
# 12    by eli wright following the fed rate hike this...  2016-12-19
# 1065  by joshua franklin oliver hirt and karen freif...  2016-12-19
# 0     at the end of last week analysts at bank of am...  2016-12-20
# 1068  by sarah n lynch washington reuters morgan sta...  2016-12-20
# 1067  by simon jessop and lawrence white london reut...  2016-12-20
# 1066  european stocks registered mixed trade on tues...  2016-12-20
# 14    the federal reserve announced last week it wou...  2016-12-20
# 1069  by jonathan saul and andrew macaskill london r...  2016-12-21
# 1045  story corrects to clarify nature of transactio...  2016-12-22
# 1048  by silvia aloisi paola arosio and pamela barba...  2016-12-23
# 1047  by edward taylor frankfurt reuters deutsche ba...  2016-12-23
# 1     a couple of days after donald trump was electe...  2016-12-23
# 1046  by karen freifeld arno schuetze and kathrin jo...  2016-12-23
# 1049  by silvia aloisi paola arosio and pamela barba...  2016-12-26
# 2     there are a few times in the life of an invest...  2016-12-29
# 1050  by sujata rao and andrey ostroukh london mosco...  2016-12-30
# 3     without question was the year of the big surpr...  2016-12-30
# 4     if you saw your barclays lon barc stock take a...  2017-01-01
#
#       Sentiment_Score
# 1064          -0.9337
# 13             0.9780
# 12             0.9984
# 1065           0.9675
# 0              0.0094
# 1068          -0.7759
# 1067           0.9726
# 1066           0.9923
# 14             0.9978
# 1069          -0.9538
# 1045          -0.0580
# 1048          -0.9405
# 1047           0.9938
# 1              0.9930
# 1046           0.9781
# 1049          -0.9405
# 2              0.9990
# 1050           0.9970
# 3              0.9997
# 4              0.9749

# %%
news_clean['Negative'] = [0] * len(news_clean)
news_clean['Neutral'] = [0] * len(news_clean)
news_clean['Positive'] = [0] * len(news_clean)

for i in range(len(news_clean)):
    if news_clean.Sentiment_Score[i] < 0:
        news_clean.Negative[i] = 1
    elif news_clean.Sentiment_Score[i] > 0:
        news_clean.Positive[i] = 1
    else:
        news_clean.Neutral[i] = 1
        
news_clean.tail(20)
# Out:
#                                                 content        date  \
# 1064  by andreas kr ner and karen freifeld frankfurt...  2016-12-19
# 13    another bullish voice given that many of the c...  2016-12-19
# 12    by eli wright following the fed rate hike this...  2016-12-19
# 1065  by joshua franklin oliver hirt and karen freif...  2016-12-19
# 0     at the end of last week analysts at bank of am...  2016-12-20
# 1068  by sarah n lynch washington reuters morgan sta...  2016-12-20
# 1067  by simon jessop and lawrence white london reut...  2016-12-20
# 1066  european stocks registered mixed trade on tues...  2016-12-20
# 14    the federal reserve announced last week it wou...  2016-12-20
# 1069  by jonathan saul and andrew macaskill london r...  2016-12-21
# 1045  story corrects to clarify nature of transactio...  2016-12-22
# 1048  by silvia aloisi paola arosio and pamela barba...  2016-12-23
# 1047  by edward taylor frankfurt reuters deutsche ba...  2016-12-23
# 1     a couple of days after donald trump was electe...  2016-12-23
# 1046  by karen freifeld arno schuetze and kathrin jo...  2016-12-23
# 1049  by silvia aloisi paola arosio and pamela barba...  2016-12-26
# 2     there are a few times in the life of an invest...  2016-12-29
# 1050  by sujata rao and andrey ostroukh london mosco...  2016-12-30
# 3     without question was the year of the big surpr...  2016-12-30
# 4     if you saw your barclays lon barc stock take a...  2017-01-01
#
#       Sentiment_Score  Negative  Neutral  Positive
# 1064          -0.9337         1        0         0
# 13             0.9780         0        0         1
# 12             0.9984         0        0         1
# 1065           0.9675         0        0         1
# 0              0.0094         0        0         1
# 1068          -0.7759         1        0         0
# 1067           0.9726         0        0         1
# 1066           0.9923         0        0         1
# 14             0.9978         0        0         1
# 1069          -0.9538         1        0         0
# 1045          -0.0580         1        0         0
# 1048          -0.9405         1        0         0
# 1047           0.9938         0        0         1
# 1              0.9930         0        0         1
# 1046           0.9781         0        0         1
# 1049          -0.9405         1        0         0
# 2              0.9990         0        0         1
# 1050           0.9970         0        0         1
# 3              0.9997         0        0         1
# 4              0.9749         0        0         1

# %%
news_clean_3 = news_clean[['date', 'Negative', 'Neutral', 'Positive']]
news_clean_3 = news_clean_3.groupby('date').mean()
news_clean_3.tail(20)
# Out:
#             Negative   Neutral  Positive
# date
# 2016-12-06  0.000000  0.000000  1.000000
# 2016-12-07  0.000000  0.000000  1.000000
# 2016-12-08  0.181818  0.000000  0.818182
# 2016-12-09  0.000000  0.000000  1.000000
# 2016-12-12  0.000000  0.000000  1.000000
# 2016-12-13  0.250000  0.000000  0.750000
# 2016-12-14  1.000000  0.000000  0.000000
# 2016-12-15  0.333333  0.000000  0.666667
# 2016-12-16  0.333333  0.333333  0.333333
# 2016-12-17  0.000000  0.000000  1.000000
# 2016-12-18  0.000000  0.000000  1.000000
# 2016-12-19  0.250000  0.000000  0.750000
# 2016-12-20  0.200000  0.000000  0.800000
# 2016-12-21  1.000000  0.000000  0.000000
# 2016-12-22  1.000000  0.000000  0.000000
# 2016-12-23  0.250000  0.000000  0.750000
# 2016-12-26  1.000000  0.000000  0.000000
# 2016-12-29  0.000000  0.000000  1.000000
# 2016-12-30  0.000000  0.000000  1.000000
# 2017-01-01  0.000000  0.000000  1.000000

# %%
news_clean_3.to_csv('news_vader_avg.csv')
